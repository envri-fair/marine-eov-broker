# %%
from marine_eov_broker import MarineRiBroker
import logging
import matplotlib.pyplot as plt

logger = logging.getLogger()
logger.setLevel(logging.INFO)
# logger.setLevel(logging.DEBUG)

print(MarineRiBroker.ERDDAP_OUTPUT_FORMATS)
print(MarineRiBroker.EOV_LIST)
# Out:
# ['csv', 'geoJson', 'json', 'nc', 'ncCF', 'odvTxt']
# ['EV_SEATEMP', 'EV_SALIN', 'EV_OXY', 'EV_CURR', 'EV_CHLA', 'EV_CO2', 'EV_NUTS']

# %%
broker = MarineRiBroker.MarineBroker({"https://www.ifremer.fr/erddap": ["ArgoFloats-synthetic-BGC"]})


#eovs_request = ["EV_SALIN", "EV_OXY", "EV_SEATEMP"]
eovs_request = ["EV_OXY"]

start_date = "2022-01-16"
end_date = "2022-01-17"
# North-east Atlantic Ocean
min_lon = -40
min_lat = 35
max_lon = 2
max_lat = 62

query_filename = "platform_finder.sparql"
variables = {
"start_date" : start_date,
"end_date" : end_date,
"min_lon" : min_lon,
"min_lat" : min_lat,
"max_lon" : max_lon,
"max_lat" : max_lat,
}
# logger.setLevel(logging.DEBUG)
# Out:
# fock
# [<Future at 0x7f8642bfb7f0 state=running>]
# fock
# [<Future at 0x7f8642bfb7f0 state=running>, <Future at 0x7f8642bfbc10 state=running>]
# fock
# [<Future at 0x7f8642bfb7f0 state=running>, <Future at 0x7f8642bfbc10 state=running>, <Future at 0x7f868f0c7130 state=running>]
# fock
# [<Future at 0x7f8642bfb7f0 state=running>, <Future at 0x7f8642bfbc10 state=running>, <Future at 0x7f868f0c7130 state=running>, <Future at 0x7f868f0c6f80 state=running>]
# fock
# [<Future at 0x7f8642bfb7f0 state=running>, <Future at 0x7f8642bfbc10 state=running>, <Future at 0x7f868f0c7130 state=running>, <Future at 0x7f868f0c6f80 state=running>, <Future at 0x7f868f0c56f0 state=running>]
# fock
# [<Future at 0x7f8642bfb7f0 state=running>, <Future at 0x7f8642bfbc10 state=running>, <Future at 0x7f868f0c7130 state=running>, <Future at 0x7f868f0c6f80 state=running>, <Future at 0x7f868f0c56f0 state=running>, <Future at 0x7f8642a24b50 state=running>]
# fock
# ...

# %%
ddata = [{'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/PSSTRT01/', 'P01not': 'SDN:P01::PSSTRT01', 'p01lbl': 'Temperature of surface microlayer {skin temperature} of the water body by infra-red radiometer', 'P02not': 'SDN:P02::PSST'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAV01/', 'P01not': 'SDN:P01::TEMPAV01', 'p01lbl': 'Temperature of surface microlayer {skin temperature} of the water body by advanced very high resolution radiometer (AVHRR)', 'P02not': 'SDN:P02::PSST'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMWRD/', 'P01not': 'SDN:P01::TEMPMWRD', 'p01lbl': 'Temperature of surface microlayer {subskin temperature} of the water body by microwave radiometer', 'P02not': 'SDN:P02::PSST'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST01/', 'P01not': 'SDN:P01::TEMPST01', 'p01lbl': 'Temperature of the water body by CTD or STD', 'R03not': 'SDN:R03::TEMP', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC03/', 'P01not': 'SDN:P01::TEMPTC03', 'p01lbl': 'Temperature of the water body by in-situ thermistor (third sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE12', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE03', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE06', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE02', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE05', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE09', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE10', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE08', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE01', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE11', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE04', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TE07', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'P01not': 'SDN:P01::TEMPPR01', 'p01lbl': 'Temperature of the water body', 'P09not': 'SDN:P09::TEMP', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMC01/', 'P01not': 'SDN:P01::TEMPMC01', 'p01lbl': 'Temperature of the water body by moving vessel profiler (MVP) and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAPRT/', 'P01not': 'SDN:P01::TEMPAPRT', 'p01lbl': 'Temperature of the water body by AWQMS Quanta platinum resistance thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC14/', 'P01not': 'SDN:P01::TEMPTC14', 'p01lbl': 'Temperature of the water body by in-situ thermistor (fourteenth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCU01/', 'P01not': 'SDN:P01::TEMPCU01', 'p01lbl': 'Temperature of the water body by CTD and NO verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC10/', 'P01not': 'SDN:P01::TEMPTC10', 'p01lbl': 'Temperature of the water body by in-situ thermistor (tenth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPR901/', 'P01not': 'SDN:P01::TEMPR901', 'p01lbl': 'Temperature (ITS-90) of the water body by reversing thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPP01/', 'P01not': 'SDN:P01::TEMPPP01', 'p01lbl': 'Temperature of the water body by YSI in-situ oxygen and temperature probe', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC13/', 'P01not': 'SDN:P01::TEMPTC13', 'p01lbl': 'Temperature of the water body by in-situ thermistor (thirteenth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHU01/', 'P01not': 'SDN:P01::TEMPHU01', 'p01lbl': 'Temperature of the water body by thermosalinograph hull sensor and NO verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHG02/', 'P01not': 'SDN:P01::TEMPHG02', 'p01lbl': 'Temperature of the water body by thermosalinograph hull sensor (second sensor) and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR03/', 'P01not': 'SDN:P01::TEMPPR03', 'p01lbl': 'Temperature of the water body by third sensor', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCC02/', 'P01not': 'SDN:P01::TEMPCC02', 'p01lbl': 'Temperature of the water body by CTD and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC09/', 'P01not': 'SDN:P01::TEMPTC09', 'p01lbl': 'Temperature of the water body by in-situ thermistor (ninth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHG01/', 'P01not': 'SDN:P01::TEMPHG01', 'p01lbl': 'Temperature of the water body by thermosalinograph hull sensor and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPRTNX/', 'P01not': 'SDN:P01::TEMPRTNX', 'p01lbl': 'Temperature of the water body by reversing thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSG01/', 'P01not': 'SDN:P01::TEMPSG01', 'p01lbl': 'Temperature of the water body by thermosalinograph and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC11/', 'P01not': 'SDN:P01::TEMPTC11', 'p01lbl': 'Temperature of the water body by in-situ thermistor (eleventh sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TMCLCCI1/', 'P01not': 'SDN:P01::TMCLCCI1', 'p01lbl': 'Temperature of the water body by in-situ thermometer and calibration against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHGNX/', 'P01not': 'SDN:P01::TEMPHGNX', 'p01lbl': 'Temperature of the water body by hand-held mercury thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS601/', 'P01not': 'SDN:P01::TEMPS601', 'p01lbl': 'Temperature (IPTS-68) of the water body by CTD or STD', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPDTNX/', 'P01not': 'SDN:P01::TEMPDTNX', 'p01lbl': 'Temperature of the water body by hand-held digital thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR02/', 'P01not': 'SDN:P01::TEMPPR02', 'p01lbl': 'Temperature of the water body by second sensor', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPET01/', 'P01not': 'SDN:P01::TEMPET01', 'p01lbl': 'Temperature of the water body by expendable bathythermograph (XBT)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPP901/', 'P01not': 'SDN:P01::TEMPP901', 'p01lbl': 'Temperature (ITS-90) of the water body', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC01/', 'P01not': 'SDN:P01::TEMPTC01', 'p01lbl': 'Temperature of the water body by in-situ thermistor', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPP02/', 'P01not': 'SDN:P01::TEMPPP02', 'p01lbl': 'Temperature of the water body by YSI profiling oxygen and temperature probe', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMT01/', 'P01not': 'SDN:P01::TEMPMT01', 'p01lbl': 'Temperature of the water body by mechanical bathythermograph', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCC01/', 'P01not': 'SDN:P01::TEMPCC01', 'p01lbl': 'Temperature of the water body by CTD and verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSU01/', 'P01not': 'SDN:P01::TEMPSU01', 'p01lbl': 'Temperature of the water body by thermosalinograph and NO verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPBT01/', 'P01not': 'SDN:P01::TEMPBT01', 'p01lbl': 'Temperature of the water body by bathythermograph', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC05/', 'P01not': 'SDN:P01::TEMPTC05', 'p01lbl': 'Temperature of the water body by in-situ thermistor (fifth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTADC/', 'P01not': 'SDN:P01::TEMPTADC', 'p01lbl': 'Temperature of the water body by in-situ thermistor on acoustic doppler current profiler (ADCP) transducer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TMCLCCL1/', 'P01not': 'SDN:P01::TMCLCCL1', 'p01lbl': 'Temperature of the water body by in-situ thermometer and laboratory calibration applied', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTB01/', 'P01not': 'SDN:P01::TEMPTB01', 'p01lbl': 'Temperature of the water body by in-situ StowAway TidbiT temperature logger', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPP681/', 'P01not': 'SDN:P01::TEMPP681', 'p01lbl': 'Temperature (IPTS-68) of the water body', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS901/', 'P01not': 'SDN:P01::TEMPS901', 'p01lbl': 'Temperature (ITS-90) of the water body by CTD or STD', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC12/', 'P01not': 'SDN:P01::TEMPTC12', 'p01lbl': 'Temperature of the water body by in-situ thermistor (twelfth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPH01/', 'P01not': 'SDN:P01::TEMPPH01', 'p01lbl': 'Temperature of the water body by temperature probe on half tide pressure gauge', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC08/', 'P01not': 'SDN:P01::TEMPTC08', 'p01lbl': 'Temperature of the water body by in-situ thermistor (eighth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC07/', 'P01not': 'SDN:P01::TEMPTC07', 'p01lbl': 'Temperature of the water body by in-situ thermistor (seventh sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS902/', 'P01not': 'SDN:P01::TEMPS902', 'p01lbl': 'Temperature (ITS-90) of the water body by CTD or STD (second sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC04/', 'P01not': 'SDN:P01::TEMPTC04', 'p01lbl': 'Temperature of the water body by in-situ thermistor (fourth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC15/', 'P01not': 'SDN:P01::TEMPTC15', 'p01lbl': 'Temperature of the water body by in-situ thermistor (fifteenth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC06/', 'P01not': 'SDN:P01::TEMPTC06', 'p01lbl': 'Temperature of the water body by in-situ thermistor (sixth sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPR601/', 'P01not': 'SDN:P01::TEMPR601', 'p01lbl': 'Temperature (IPTS-68) of the water body by reversing thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/PSSTTS01/', 'P01not': 'SDN:P01::PSSTTS01', 'p01lbl': 'Temperature of the water body by in-situ thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSZ01/', 'P01not': 'SDN:P01::TEMPSZ01', 'p01lbl': 'Temperature of the water body by thermosalinograph', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMP01/', 'P01not': 'SDN:P01::TEMPMP01', 'p01lbl': 'Temperature of the water body by model prediction', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC02/', 'P01not': 'SDN:P01::TEMPTC02', 'p01lbl': 'Temperature of the water body by in-situ thermistor (second sensor)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHU02/', 'P01not': 'SDN:P01::TEMPHU02', 'p01lbl': 'Temperature of the water body by thermosalinograph hull sensor (second sensor) and NO verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSB35/', 'P01not': 'SDN:P01::TEMPSB35', 'p01lbl': 'Temperature of the water body by Sea-Bird SBE 35 deep ocean standards thermometer', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCU02/', 'P01not': 'SDN:P01::TEMPCU02', 'p01lbl': 'Temperature of the water body by CTD (second sensor) and NO verification against independent measurements', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMV01/', 'P01not': 'SDN:P01::TEMPMV01', 'p01lbl': 'Temperature of the water body by moving vessel profiler (MVP)', 'P02not': 'SDN:P02::TEMP'}, {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST02/', 'P01not': 'SDN:P01::TEMPST02', 'p01lbl': 'Temperature of the water body by CTD or STD (second sensor)', 'P02not': 'SDN:P02::TEMP'}]

# %%
qqdict = {'p01_mem': ['http://vocab.nerc.ac.uk/collection/P01/current/PSSTRT01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAV01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMWRD/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC03/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMC01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAPRT/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC14/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCU01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC10/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPR901/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPP01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC13/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHU01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHG02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR03/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCC02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC09/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHG01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPRTNX/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSG01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC11/', 'http://vocab.nerc.ac.uk/collection/P01/current/TMCLCCI1/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHGNX/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS601/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPDTNX/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPET01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPP901/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPP02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMT01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCC01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSU01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPBT01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC05/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTADC/', 'http://vocab.nerc.ac.uk/collection/P01/current/TMCLCCL1/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTB01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPP681/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS901/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC12/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPH01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC08/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC07/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPS902/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC04/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC15/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC06/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPR601/', 'http://vocab.nerc.ac.uk/collection/P01/current/PSSTTS01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSZ01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMP01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPHU02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPSB35/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPCU02/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMV01/', 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST02/'], 'P01not': ['SDN:P01::PSSTRT01', 'SDN:P01::TEMPAV01', 'SDN:P01::TEMPMWRD', 'SDN:P01::TEMPST01', 'SDN:P01::TEMPTC03', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPPR01', 'SDN:P01::TEMPMC01', 'SDN:P01::TEMPAPRT', 'SDN:P01::TEMPTC14', 'SDN:P01::TEMPCU01', 'SDN:P01::TEMPTC10', 'SDN:P01::TEMPR901', 'SDN:P01::TEMPPP01', 'SDN:P01::TEMPTC13', 'SDN:P01::TEMPHU01', 'SDN:P01::TEMPHG02', 'SDN:P01::TEMPPR03', 'SDN:P01::TEMPCC02', 'SDN:P01::TEMPTC09', 'SDN:P01::TEMPHG01', 'SDN:P01::TEMPRTNX', 'SDN:P01::TEMPSG01', 'SDN:P01::TEMPTC11', 'SDN:P01::TMCLCCI1', 'SDN:P01::TEMPHGNX', 'SDN:P01::TEMPS601', 'SDN:P01::TEMPDTNX', 'SDN:P01::TEMPPR02', 'SDN:P01::TEMPET01', 'SDN:P01::TEMPP901', 'SDN:P01::TEMPTC01', 'SDN:P01::TEMPPP02', 'SDN:P01::TEMPMT01', 'SDN:P01::TEMPCC01', 'SDN:P01::TEMPSU01', 'SDN:P01::TEMPBT01', 'SDN:P01::TEMPTC05', 'SDN:P01::TEMPTADC', 'SDN:P01::TMCLCCL1', 'SDN:P01::TEMPTB01', 'SDN:P01::TEMPP681', 'SDN:P01::TEMPS901', 'SDN:P01::TEMPTC12', 'SDN:P01::TEMPPH01', 'SDN:P01::TEMPTC08', 'SDN:P01::TEMPTC07', 'SDN:P01::TEMPS902', 'SDN:P01::TEMPTC04', 'SDN:P01::TEMPTC15', 'SDN:P01::TEMPTC06', 'SDN:P01::TEMPR601', 'SDN:P01::PSSTTS01', 'SDN:P01::TEMPSZ01', 'SDN:P01::TEMPMP01', 'SDN:P01::TEMPTC02', 'SDN:P01::TEMPHU02', 'SDN:P01::TEMPSB35', 'SDN:P01::TEMPCU02', 'SDN:P01::TEMPMV01', 'SDN:P01::TEMPST02'], 'p01lbl': ['Temperature of surface microlayer {skin temperature} of the water body by infra-red radiometer', 'Temperature of surface microlayer {skin temperature} of the water body by advanced very high resolution radiometer (AVHRR)', 'Temperature of surface microlayer {subskin temperature} of the water body by microwave radiometer', 'Temperature of the water body by CTD or STD', 'Temperature of the water body by in-situ thermistor (third sensor)', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body', 'Temperature of the water body by moving vessel profiler (MVP) and verification against independent measurements', 'Temperature of the water body by AWQMS Quanta platinum resistance thermometer', 'Temperature of the water body by in-situ thermistor (fourteenth sensor)', 'Temperature of the water body by CTD and NO verification against independent measurements', 'Temperature of the water body by in-situ thermistor (tenth sensor)', 'Temperature (ITS-90) of the water body by reversing thermometer', 'Temperature of the water body by YSI in-situ oxygen and temperature probe', 'Temperature of the water body by in-situ thermistor (thirteenth sensor)', 'Temperature of the water body by thermosalinograph hull sensor and NO verification against independent measurements', 'Temperature of the water body by thermosalinograph hull sensor (second sensor) and verification against independent measurements', 'Temperature of the water body by third sensor', 'Temperature of the water body by CTD and verification against independent measurements', 'Temperature of the water body by in-situ thermistor (ninth sensor)', 'Temperature of the water body by thermosalinograph hull sensor and verification against independent measurements', 'Temperature of the water body by reversing thermometer', 'Temperature of the water body by thermosalinograph and verification against independent measurements', 'Temperature of the water body by in-situ thermistor (eleventh sensor)', 'Temperature of the water body by in-situ thermometer and calibration against independent measurements', 'Temperature of the water body by hand-held mercury thermometer', 'Temperature (IPTS-68) of the water body by CTD or STD', 'Temperature of the water body by hand-held digital thermometer', 'Temperature of the water body by second sensor', 'Temperature of the water body by expendable bathythermograph (XBT)', 'Temperature (ITS-90) of the water body', 'Temperature of the water body by in-situ thermistor', 'Temperature of the water body by YSI profiling oxygen and temperature probe', 'Temperature of the water body by mechanical bathythermograph', 'Temperature of the water body by CTD and verification against independent measurements', 'Temperature of the water body by thermosalinograph and NO verification against independent measurements', 'Temperature of the water body by bathythermograph', 'Temperature of the water body by in-situ thermistor (fifth sensor)', 'Temperature of the water body by in-situ thermistor on acoustic doppler current profiler (ADCP) transducer', 'Temperature of the water body by in-situ thermometer and laboratory calibration applied', 'Temperature of the water body by in-situ StowAway TidbiT temperature logger', 'Temperature (IPTS-68) of the water body', 'Temperature (ITS-90) of the water body by CTD or STD', 'Temperature of the water body by in-situ thermistor (twelfth sensor)', 'Temperature of the water body by temperature probe on half tide pressure gauge', 'Temperature of the water body by in-situ thermistor (eighth sensor)', 'Temperature of the water body by in-situ thermistor (seventh sensor)', 'Temperature (ITS-90) of the water body by CTD or STD (second sensor)', 'Temperature of the water body by in-situ thermistor (fourth sensor)', 'Temperature of the water body by in-situ thermistor (fifteenth sensor)', 'Temperature of the water body by in-situ thermistor (sixth sensor)', 'Temperature (IPTS-68) of the water body by reversing thermometer', 'Temperature of the water body by in-situ thermometer', 'Temperature of the water body by thermosalinograph', 'Temperature of the water body by model prediction', 'Temperature of the water body by in-situ thermistor (second sensor)', 'Temperature of the water body by thermosalinograph hull sensor (second sensor) and NO verification against independent measurements', 'Temperature of the water body by Sea-Bird SBE 35 deep ocean standards thermometer', 'Temperature of the water body by CTD (second sensor) and NO verification against independent measurements', 'Temperature of the water body by moving vessel profiler (MVP)', 'Temperature of the water body by CTD or STD (second sensor)'], 'P02not': ['SDN:P02::PSST', 'SDN:P02::PSST', 'SDN:P02::PSST', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP', 'SDN:P02::TEMP'], 'R03not': ['SDN:R03::TEMP'], 'P09not': ['SDN:P09::TE12', 'SDN:P09::TE03', 'SDN:P09::TE06', 'SDN:P09::TE02', 'SDN:P09::TE05', 'SDN:P09::TE09', 'SDN:P09::TE10', 'SDN:P09::TE08', 'SDN:P09::TE01', 'SDN:P09::TE11', 'SDN:P09::TE04', 'SDN:P09::TE07', 'SDN:P09::TEMP']}

# %%
ddata
# Out:
# [{'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/PSSTRT01/',
#   'P01not': 'SDN:P01::PSSTRT01',
#   'p01lbl': 'Temperature of surface microlayer {skin temperature} of the water body by infra-red radiometer',
#   'P02not': 'SDN:P02::PSST'},
#  {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAV01/',
#   'P01not': 'SDN:P01::TEMPAV01',
#   'p01lbl': 'Temperature of surface microlayer {skin temperature} of the water body by advanced very high resolution radiometer (AVHRR)',
#   'P02not': 'SDN:P02::PSST'},
#  {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMWRD/',
#   'P01not': 'SDN:P01::TEMPMWRD',
#   'p01lbl': 'Temperature of surface microlayer {subskin temperature} of the water body by microwave radiometer',
#   'P02not': 'SDN:P02::PSST'},
#  {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST01/',
#   'P01not': 'SDN:P01::TEMPST01',
#   'p01lbl': 'Temperature of the water body by CTD or STD',
#   'R03not': 'SDN:R03::TEMP',
# ...

# %%
qqdict
# Out:
# {'p01_mem': ['http://vocab.nerc.ac.uk/collection/P01/current/PSSTRT01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPAV01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPMWRD/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPST01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPTC03/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
#   'http://vocab.nerc.ac.uk/collection/P01/current/TEMPPR01/',
# ...

# %%
from pykg2tbl.j2.jinja_sparql_builder import J2SparqlBuilder
from pysubyt.j2.functions import Filters, Functions

template_folder = "src/marine_eov_broker/j2_templates"

j2sqb = J2SparqlBuilder(template_folder, j2_filters=Filters, j2_functions=Functions)

query_filename = "platform_finder.sparql"
variables = {
"start_date" : start_date,
"end_date" : end_date,
"min_lon" : min_lon,
"min_lat" : min_lat,
"max_lon" : max_lon,
"max_lat" : max_lat,
}

qry = j2sqb.build_sparql_query(query_filename, **variables)
print(qry)

response = broker.submit_sparql_query(qry, broker.DEFAULT_SPARQL_ENDPOINTS["Argo"], 
     eovs_request, 
     start_date,
     end_date,
     min_lon,
     min_lat,
     max_lon,
     max_lat,
     "nc",
     "platform_number",
     "ArgoFloats-synthetic-BGC")

# %%
response = broker.submit_sparql_query("""
prefix geo: <https://www.w3.org/2003/01/geo/wgs84_pos#>
prefix owl: <http://www.w3.org/2002/07/owl#>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
prefix ssn: <http://www.w3.org/ns/ssn/> 
prefix xml: <http://www.w3.org/XML/1998/namespace> 
prefix xsd: <http://www.w3.org/2001/XMLSchema#> 
prefix argo: <https://co.ifremer.fr/co/argo-linked-data/doc/argo-floats.ttl#> 
prefix foaf: <http://xmlns.com/foaf/0.1/> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix sosa: <http://www.w3.org/ns/sosa/>
prefix nerc: <http://vocab.nerc.ac.uk/collection/>
prefix dct: <http://purl.org/dc/terms/>
prefix prov: <https://www.w3.org/TR/prov-o/>
prefix dcat: <http://www.w3.org/ns/dcat#>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?platform_number ?lat ?lon WHERE { 
# ?float a dcat:Dataset;
       dct:identifier ?platform_number;
       argo:cycle ?cycle;
       sosa:hosts ?sensor.
# ?sensor sosa:observes <http://vocab.nerc.ac.uk/collection/R03/current/DOXY>.
# ?cycle argo:startDate ?date;
       geo:latitude ?lat;
       geo:longitude ?lon.

FILTER(?lat >= 35)
FILTER(?lat <= 62)
FILTER(?lon >= -40)
FILTER(?lon <= 2)
FILTER(?date >= "2022-01-16"^^xsd:date)
FILTER(?date <= "2022-01-17"^^xsd:date)
}
""", broker.DEFAULT_SPARQL_ENDPOINTS["Argo"], 
     eovs_request, 
     start_date,
     end_date,
     min_lon,
     min_lat,
     max_lon,
     max_lat,
     "nc",
     "platform_number",
     "ArgoFloats-synthetic-BGC")

# %%
response.compile_results()
# Out:
#                    time   latitude  longitude       psal        doxy  \
# row
# 0   2022-01-16 07:02:00  44.389088  -20.07749  35.784000  230.547607
# 1   2022-01-16 07:02:00  44.389088  -20.07749  35.784000         NaN
# 2   2022-01-16 07:02:00  44.389088  -20.07749  35.784668  230.644394
# 3   2022-01-16 07:02:00  44.389088  -20.07749  35.785000         NaN
# 4   2022-01-16 07:02:00  44.389088  -20.07749  35.784000         NaN
# ..                  ...        ...        ...        ...         ...
# 505 2022-01-16 04:15:45  42.600000  -16.77500  34.978001  246.669815
# 506 2022-01-16 04:15:45  42.600000  -16.77500  34.974998  246.785339
# 507 2022-01-16 04:15:45  42.600000  -16.77500  34.973999  246.422516
# 508 2022-01-16 04:15:45  42.600000  -16.77500  34.970001  246.775803
# 509 2022-01-16 04:15:45  42.600000  -16.77500  34.956001  239.572922
#
#      mlpl_doxy       temp         pres
# row
# 0          NaN  14.548000     0.700000
# 1          NaN  14.548000     1.000000
# ...

# %%
query_result.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 query_result.to_list()
#
# NameError: name 'query_result' is not defined

# %%
query_result.to_dataframe()

# %%
query_result.to_dict()

# %%
broker.query_vocabularies("EV_OXY")

# %%
a = [{'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXMZZXX/',
  'P01not': 'SDN:P01::DOXMZZXX',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit mass of the water body [dissolved plus reactive particulate phase]',
  'R03not': 'SDN:R03::DOXY',
  'P09not': 'SDN:P09::DOX2',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYAAOP/',
  'P01not': 'SDN:P01::DOXYAAOP',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by optode',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/OXYSMOD1/',
  'P01not': 'SDN:P01::OXYSMOD1',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by model prediction',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSU02/',
  'P01not': 'SDN:P01::DOXYSU02',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor (second sensor) and no calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYZZXX/',
  'P01not': 'SDN:P01::DOXYZZXX',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase]',
  'R03not': 'SDN:R03::MLPL_DOXY',
  'P09not': 'SDN:P09::DOXY',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYZZXX/',
  'P01not': 'SDN:P01::DOXYZZXX',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase]',
  'R03not': 'SDN:R03::MLPL_DOXY',
  'P09not': 'SDN:P09::DOX1',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSC01/',
  'P01not': 'SDN:P01::DOXYSC01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor and calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYPR01/',
  'P01not': 'SDN:P01::DOXYPR01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ Beckmann probe',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSC02/',
  'P01not': 'SDN:P01::DOXYSC02',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor (second sensor) and calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSE02/',
  'P01not': 'SDN:P01::DOXYSE02',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by YSI profiling oxygen and temperature probe',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYPR02/',
  'P01not': 'SDN:P01::DOXYPR02',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ Beckmann probe (second sensor)',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYUZ02/',
  'P01not': 'SDN:P01::DOXYUZ02',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ sensor (second sensor) and no calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYCZ01/',
  'P01not': 'SDN:P01::DOXYCZ01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ sensor and calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYPE01/',
  'P01not': 'SDN:P01::DOXYPE01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ pulsed electrode',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYZZ01/',
  'P01not': 'SDN:P01::DOXYZZ01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ sensor',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSE01/',
  'P01not': 'SDN:P01::DOXYSE01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by YSI in-situ oxygen and temperature probe',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYOP01/',
  'P01not': 'SDN:P01::DOXYOP01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ oxygen optode',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYWITX/',
  'P01not': 'SDN:P01::DOXYWITX',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by Winkler titration',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYUZ01/',
  'P01not': 'SDN:P01::DOXYUZ01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by in-situ sensor and no calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSU01/',
  'P01not': 'SDN:P01::DOXYSU01',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor and no calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOKGWITX/',
  'P01not': 'SDN:P01::DOKGWITX',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit mass of the water body [dissolved plus reactive particulate phase] by Winkler titration',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYSCKG/',
  'P01not': 'SDN:P01::DOXYSCKG',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit mass of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor and calibration against sample data',
  'P02not': 'SDN:P02::DOXY'},
 {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/DOXYUCKG/',
  'P01not': 'SDN:P01::DOXYUCKG',
  'p01lbl': 'Concentration of oxygen {O2 CAS 7782-44-7} per unit mass of the water body [dissolved plus reactive particulate phase] by Sea-Bird SBE 43 sensor and no calibration against sample data',
  'P02not': 'SDN:P02::DOXY'}]

# %%
len(a)
# Out:
# 23

# %%
eovs_request = ["EV_SALIN", "EV_OXY", "EV_SEATEMP"]

for eov in eovs_request:

    rrr = broker.query_vocabularies(eov)
    print(len(rrr))
    print(rrr[0])
    for r in rrr:
        print(r.keys())
# Out:
# 33
# {'p01_mem': 'http://vocab.nerc.ac.uk/collection/P01/current/PSALST01/', 'P01not': 'SDN:P01::PSALST01', 'p01lbl': 'Practical salinity of the water body by CTD and computation using UNESCO 1983 algorithm', 'R03not': 'SDN:R03::PSAL', 'P02not': 'SDN:P02::PSAL'}
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'R03not', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# dict_keys(['p01_mem', 'P01not', 'p01lbl', 'P02not'])
# ...

# %%
    found_vars = broker.find_eov_in_dataset(broker.datasets[0], "EV_SALIN", broker.vocabularies[eov])

# %%
found_vars[0]
# Out:
# 'temp'
